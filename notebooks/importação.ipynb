# %%
import requests
import json

# %%
url_integrate = "https://identity.us.mixtelematics.com/core/connect/token"

# %%
payload = 'grant_type=password&username=flavislei.costa%40hptransportes.com.br&password=flavisleicosta2024&scope=offline_access%20MiX.Integrate'

# %%
headers = {
  'Content-Type': 'application/x-www-form-urlencoded',
  'Authorization': 'Basic bWl4YnJocHRyYW5zcG9ydGVzOmlBMTA4NmQ2aWhoUUZzV0Y='
}

# %%
response = requests.request("POST", url_integrate, headers=headers, data=payload)

# %%
data = json.loads(response.text)

# %%
access_token = data['access_token']

# %%
url_stream = "https://integrate.us.mixtelematics.com//api/geodata/assetmovements/-8537705117441354628/20240322100000/20240322141200"

# %%
payload = {}
headers = {
  'Authorization': f'Bearer {access_token}'
}

response = requests.request("GET", url_stream, headers=headers, data=payload)

print(response.text)
# Out:
# { "type": "FeatureCollection", "features": [{ "type": "Feature", "properties": { "Registration": "SCQ3A44", "Description": "20805"}, "geometry": { "type": "LineString", "coordinates": [[-49.308409,-16.712392], [-49.310137,-16.711373], [-49.310383,-16.710986], [-49.310621,-16.710987], [-49.310639,-16.710819], [-49.310670,-16.710017], [-49.310643,-16.709660], [-49.310443,-16.709627], [-49.310405,-16.709789], [-49.310329,-16.710481], [-49.310324,-16.710728], [-49.310350,-16.711019], [-49.310447,-16.711071], [-49.310555,-16.711079], [-49.310582,-16.711064], [-49.310637,-16.710898], [-49.310626,-16.709647], [-49.310467,-16.709587], [-49.309491,-16.709529], [-49.309390,-16.709819], [-49.309186,-16.712168], [-49.308532,-16.712731], [-49.307950,-16.712773], [-49.307130,-16.715446], [-49.306696,-16.716882], [-49.306428,-16.717493], [-49.305130,-16.718133], [-49.304861,-16.718272], [-49.303832,-16.719902], [-49.303305,-16.721362], [-49.303091,-16.721293], [-49.300334,-16.720176], [-49.297218,-
# ...
